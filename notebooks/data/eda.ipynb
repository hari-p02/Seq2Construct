# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/Users/haripat/Desktop/SF/protein/data/protein_constructs_w_label_masks.xlsx")

# %%
df.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'rcsb_id',
#        'rcsb_entity_ids', 'uniprot_seq', 'pbd_id', 'pdb_sequence_sanitized',
#        'label_mask'],
#       dtype='object')

# %%
df['uniprot_seq'].apply(len).hist(bins=100, edgecolor='black')

plt.title('Distribution of UniProt Sequence Lengths')
plt.xlabel('Sequence Length')
plt.ylabel('Frequency')
plt.show()

# %%
lengths = df['uniprot_seq'].str.len()
percentile = (lengths <= 3000).mean() * 100

print(f"The size 2000 is at the {percentile:.2f}th percentile.")
# Out:
# The size 2000 is at the 99.47th percentile.

# %%
import torch

# %%
ankh_embeddings = torch.load("/Users/haripat/Downloads/ankh_embeddings.pt")

# %%
ankh_embeddings
# Out:
# tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]])
